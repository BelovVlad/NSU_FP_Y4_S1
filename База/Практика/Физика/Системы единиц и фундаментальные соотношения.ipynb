# %% [markdown]
# # Системы единиц и фундаментальные соотношения
#
# Единицы, переводы и размерности — в отдельных блоках. Выберите тему ниже или найдите величину по названию и символу: например, «заряд», `q`, «ёмкость». В таблицах переводов слева стоит единица СИ, справа — её эквивалент в СГС.
#
# **Нужна постоянная, а не перевод?** Значения $c$, $h$, $e$, масс частиц и атомных масштабов собраны в [физических константах](Физические%20константы.ipynb).
#
# > **СГС — семейство систем.** Для механики достаточно сантиметра, грамма и секунды. Для электричества ниже применены электростатические единицы (статКл, статВ); для полей — гауссова СГС. Электрические и магнитные коэффициенты приведены с учебной точностью: не переносите формулы из СИ в СГС простой заменой названий единиц.

# %% [markdown]
# <h2 id="si-units">Единицы СИ и приставки</h2>
#
# | Величина | Обозначение | Единица СИ | Международное обозначение |
# | --- | --- | --- | --- |
# | Время | $t$ | секунда | $\mathrm{s}$ |
# | Длина | $\ell$ | метр | $\mathrm{m}$ |
# | Масса | $m$ | килограмм | $\mathrm{kg}$ |
# | Сила электрического тока | $I$ | ампер | $\mathrm{A}$ |
# | Термодинамическая температура | $T$ | кельвин | $\mathrm{K}$ |
# | Количество вещества | $\nu, n$ | $\text{моль}$ | $\mathrm{mol}$ |
# | Сила света | $I_v$ | кандела | $\mathrm{cd}$ |

# %% [markdown]
# ### Часто используемые приставки
#
# | Приставка | Символ | Множитель | Пример |
# | --- | --- | --- | --- |
# | тера | $\mathrm{T}$ | $10^{12}$ | $\text{ТГц}$ |
# | гига | $\mathrm{G}$ | $10^9$ | $\text{ГэВ}$ |
# | мега | $\mathrm{M}$ | $10^6$ | $\text{МГц}$ |
# | кило | $\mathrm{k}$ | $10^3$ | $\text{км}$ |
# | санти | $\mathrm{c}$ | $10^{-2}$ | $\text{см}$ |
# | милли | $\mathrm{m}$ | $10^{-3}$ | $\text{мм}$ |
# | микро | $\mu$ | $10^{-6}$ | $\text{мкм}$ |
# | нано | $\mathrm{n}$ | $10^{-9}$ | $\text{нм}$ |
# | пико | $\mathrm{p}$ | $10^{-12}$ | $\text{пФ}$ |
# | фемто | $\mathrm{f}$ | $10^{-15}$ | $\text{фм}$ |
# | атто | $\mathrm{a}$ | $10^{-18}$ | $\text{ас}$ |
#
# Приставка входит в степень: $1\,\text{см}^2=10^{-4}\,\text{м}^2$, $1\,\text{см}^3=10^{-6}\,\text{м}^3$. Для массы приставки присоединяют к грамму: $1\,\text{мг}$ = 10⁻⁶ кг. Регистр важен: `m` — милли, `M` — мега.

# %% [markdown]
# <h2 id="mechanics">Механика: СИ ↔ СГС</h2>

# %% [markdown]
# ### Геометрия, масса и время
#
# | Величина | Обозначение | В СИ | То же в СГС |
# | --- | --- | --- | --- |
# | Длина | $\ell$ | $1\,\text{м}$ | $10^2\,\text{см}$ |
# | Площадь | $S$ | $1\,\text{м}^{2}$ | $10^4\,\text{см}^{2}$ |
# | Объём | $V$ | $1\,\text{м}^{3}$ | $10^6\,\text{см}^{3}$ |
# | Масса | $m$ | $1\,\text{кг}$ | $10^3\,\text{г}$ |
# | Время | $t$ | $1\,\text{с}$ | $1\,\text{с}$ |

# %% [markdown]
# ### Движение, сила и импульс
#
# | Величина | Обозначение | В СИ | То же в СГС |
# | --- | --- | --- | --- |
# | Скорость | $v$ | $1\,\dfrac{\text{м}}{\text{с}}$ | $10^2\,\dfrac{\text{см}}{\text{с}}$ |
# | Ускорение | $a$ | $1\,\dfrac{\text{м}}{\text{с}^{2}}$ | $10^2\,\dfrac{\text{см}}{\text{с}^{2}}$ |
# | Сила | $F$ | $1\,\text{Н}$ | $10^5\,\text{дин}$ |
# | Импульс | $p$ | $1\,\dfrac{\text{кг}\cdot \text{м}}{\text{с}}$ | $10^5\,\dfrac{\text{г}\cdot \text{см}}{\text{с}}$ |

# %% [markdown]
# ### Энергия, давление и плотности
#
# | Величина | Обозначение | В СИ | То же в СГС |
# | --- | --- | --- | --- |
# | Плотность импульса | $p/V$ | $1\,\dfrac{\text{кг}}{\text{м}^{2}\cdot \text{с}}$ | $10^{-1}\,\dfrac{\text{г}}{\text{см}^{2}\cdot \text{с}}$ |
# | Энергия, работа | $E, W$ | $1\,\text{Дж}$ | $10^7\,\text{эрг}$ |
# | Мощность | $P$ | $1\,\text{Вт}$ | $10^7\,\dfrac{\text{эрг}}{\text{с}}$ |
# | Давление | $p$ | $1\,\text{Па}$ | $10\,\dfrac{\text{дин}}{\text{см}^{2}}$ |
# | Плотность массы | $\rho$ | $1\,\dfrac{\text{кг}}{\text{м}^{3}}$ | $10^{-3}\,\dfrac{\text{г}}{\text{см}^{3}}$ |
# | Плотность энергии | $w$ | $1\,\dfrac{\text{Дж}}{\text{м}^{3}}$ | $10\,\dfrac{\text{эрг}}{\text{см}^{3}}$ |
# | Объёмная плотность мощности | $P/V$ | $1\,\dfrac{\text{Вт}}{\text{м}^{3}}$ | $10\,\dfrac{\text{эрг}}{\text{см}^{3}\cdot \text{с}}$ |

# %% [markdown]
# ### Частота и вихревость
#
# | Величина | Обозначение | В СИ | То же в СГС |
# | --- | --- | --- | --- |
# | Частота, вихревость | $\nu,\zeta$ | $1\,\text{с}^{-1}$ | $1\,\text{с}^{-1}$ |
#
#
# **Обратный перевод:** делите на коэффициент из последнего столбца. Например, 3 г/см³ = 3000 кг/м³, а 25 дин = 2.5 × 10⁻⁴ Н.

# %% [markdown]
# ### Давление и внесистемные единицы
#
# | Единица | В СИ | Примечание |
# | --- | --- | --- |
# | $1\,\text{бар}$ | $10^5\,\text{Па}$ | Точно |
# | 1 стандартная атмосфера | $101325\,\text{Па}$ | Точно |
# | $1\,\text{Торр}$ | $\dfrac{101325}{760}\,\text{Па}$ | $\approx133.3223684\,\text{Па}$ |
# | $1\,\text{мм}$ рт. ст. | $\approx133.3224\,\text{Па}$ | Не тождествен торру при высокой точности |
# | 1 литр | $10^{-3}\,\text{м}^{3}$ | Точно |
# | 1 ангстрем | $10^{-10}\,\text{м}$ | $0.1\,\text{нм}$ |
# | 1 барн | $10^{-28}\,\text{м}^{2}$ | $100\,\text{фм}^{2}$ |

# %% [markdown]
# <h2 id="electricity">Электричество: СИ ↔ СГС</h2>
#
# **статКл = statC**, **статВ = statV**, **статА = statA**. Числа с десятичной дробью ниже округлены. Для быстрой оценки можно использовать $1\,\text{Кл}$ $\approx3\times10^9\,\text{статКл}$ и $1\,\text{статВ}$ $\approx300\,\text{В}$.

# %% [markdown]
# ### Заряд и ток
#
# | Величина | Обозначение | В СИ | Эквивалент в электростатической СГС |
# | --- | --- | --- | --- |
# | Электрический заряд | $q$ | $1\,\text{Кл}$ | $\approx2.99792458\times10^9\,\text{статКл}$ |
# | Объёмная плотность заряда | $\rho_q$ | $1\,\dfrac{\text{Кл}}{\text{м}^{3}}$ | $\approx2.99792458\times10^3\,\dfrac{\text{статКл}}{\text{см}^{3}}$ |
# | Сила тока | $I$ | $1\,\text{А}$ | $\approx2.99792458\times10^9\,\text{статА}$ |
# | Плотность тока | $j$ | $1\,\dfrac{\text{А}}{\text{м}^{2}}$ | $\approx2.99792458\times10^5\,\dfrac{\text{статА}}{\text{см}^{2}}$ |

# %% [markdown]
# ### Потенциал и электрическое поле
#
# | Величина | Обозначение | В СИ | Эквивалент в электростатической СГС |
# | --- | --- | --- | --- |
# | Потенциал, напряжение, ЭДС | $\varphi,U,\mathcal{E}$ | $1\,\text{В}$ | $\approx3.335640952\times10^{-3}\,\text{статВ}$ |
# | Электрическое поле | $E$ | $1\,\dfrac{\text{В}}{\text{м}}$ | $\approx3.335640952\times10^{-5}\,\dfrac{\text{статВ}}{\text{см}}$ |

# %% [markdown]
# ### Ёмкость, сопротивление и проводимость
#
# | Величина | Обозначение | В СИ | Эквивалент в электростатической СГС |
# | --- | --- | --- | --- |
# | Ёмкость | $C$ | $1\,\text{Ф}$ | $\approx8.987551787\times10^{11}\,\text{статФ}$ (см) |
# | Сопротивление, импеданс | $R,Z$ | $1\,\text{Ом}$ | $\approx1.112650056\times10^{-12}\,\text{статОм}$ (с/см) |
# | Проводимость | $G_\mathrm{el}=1/R$ | $1\,\text{См}$ | $\approx8.987551787\times10^{11}\,\dfrac{\text{см}}{\text{с}}$ |
# | Удельное сопротивление | $\rho_\mathrm{el}$ | $1\,\text{Ом}\cdot \text{м}$ | $\approx1.112650056\times10^{-10}\,\text{с}$ |
# | Удельная проводимость | $\sigma_\mathrm{el}$ | $1\,\dfrac{\text{См}}{\text{м}}$ | $\approx8.987551787\times10^9\,\text{с}^{-1}$ |
# | Индуктивность в электростатических единицах | $L_\mathrm{ESU}$ | $1\,\text{Гн}$ | $\approx1.112650056\times10^{-12}\,\text{статГн}$ (с²/см) |
#
#
# **См — сименс, см — сантиметр.** СтатГн относится к электростатической системе единиц; в электромагнитной СГС индуктивность выражают иначе. Всегда проверяйте систему в исходной формуле.

# %% [markdown]
# ### Поляризация и электрическое смещение
#
# В СИ: $\mathbf D=\varepsilon_0\mathbf E+\mathbf P$. В гауссовой СГС: $\mathbf D=\mathbf E+4\pi\mathbf P$.
#
# | Величина | В СИ | В гауссовой СГС |
# | --- | --- | --- |
# | Поляризация $P$ | $1\,\dfrac{\text{Кл}}{\text{м}^{2}}$ | $\approx2.99792458\times10^5\,\dfrac{\text{статКл}}{\text{см}^{2}}$ |
# | Электрическое смещение $D$ | $1\,\dfrac{\text{Кл}}{\text{м}^{2}}$ | $\approx4\pi\times2.99792458\times10^5\,\dfrac{\text{статКл}}{\text{см}^{2}}$ |
# | Относительная диэлектрическая проницаемость | $\varepsilon_r=\varepsilon/\varepsilon_0$ | То же безразмерное значение для линейной изотропной среды |
#
# Несмотря на одинаковые единицы $D$ и $P$, **их коэффициенты перевода отличаются на $4\pi$**. Абсолютную $\varepsilon$ в Ф/м нельзя отождествлять с безразмерной $\varepsilon_r$.

# %% [markdown]
# <h2 id="magnetism">Магнетизм: СИ ↔ СГС</h2>
#
# **Гс = G** (гаусс), **Э = Oe** (эрстед), **Мкс = Mx** (максвелл). Столбцы ниже связывают гауссову СГС и СИ; это стандартные учебные коэффициенты.

# %% [markdown]
# ### Поле, поток и потенциал
#
# | Величина | Обозначение | В СИ | В СГС |
# | --- | --- | --- | --- |
# | Магнитная индукция | $B$ | $1\,\text{Тл}$ | $10^4\,\text{Гс}$ |
# | Напряжённость магнитного поля | $H$ | $1\,\dfrac{\text{А}}{\text{м}}$ | $4\pi\times10^{-3}\,\text{Э}$ |
# | Магнитный поток | $\Phi$ | $1\,\text{Вб}$ | $10^8\,\text{Мкс}$ |
# | Векторный потенциал | $A$ | $1\,\dfrac{\text{Вб}}{\text{м}}$ | $10^6\,\text{Гс}\cdot \text{см}$ |

# %% [markdown]
# ### Магнитный момент и магнитная цепь
#
# | Величина | Обозначение | В СИ | В СГС |
# | --- | --- | --- | --- |
# | Магнитный момент | $\mathfrak m$ | $1\,\text{А}\cdot \text{м}^{2}$ = $1\,\dfrac{\text{Дж}}{\text{Тл}}$ | $10^3\,\dfrac{\text{эрг}}{\text{Гс}}$ = $10^3\,\mathrm{emu}$ |
# | Намагниченность | $M$ | $1\,\dfrac{\text{А}}{\text{м}}$ | $10^{-3}\,\dfrac{\mathrm{emu}}{\text{см}^{3}}$ |
# | Магнитодвижущая сила | $\mathcal F$ | $1\,\text{А}$ | $4\pi/10\,\text{Гб}$ (гильберт) |
# | Магнитное сопротивление | $\mathcal R$ | $1\,\dfrac{\text{А}}{\text{Вб}}$ | $4\pi\times10^{-9}\,\dfrac{\text{Гб}}{\text{Мкс}}$ |

# %% [markdown]
# ### Не путать H и M
#
# $$
# \text{СИ:}\quad \mathbf B=\mu_0(\mathbf H+\mathbf M),
# \qquad
# \text{СГС:}\quad \mathbf B=\mathbf H+4\pi\mathbf M.
# $$
#
# В СИ $H$ и $M$ измеряются в А/м, но их коэффициенты перевода в СГС **различаются**. Запись «намагниченность в гауссах» может означать $4\pi M$, а не $M$ — проверяйте определение в источнике.
#
# | Свойство линейной изотропной среды | СИ | Гауссова СГС |
# | --- | --- | --- |
# | Относительная магнитная проницаемость | $\mu_r=\mu/\mu_0$ | То же численное значение $\mu_r$ |
# | Магнитная восприимчивость при $M=\chi H$ | $\chi_\mathrm{SI}$ | $\chi_\mathrm{G}=\chi_\mathrm{SI}/(4\pi)$ |

# %% [markdown]
# <h2 id="transport">Вязкость, диффузия и тепло</h2>
#
# | Величина | Обозначение | В СИ | В СГС |
# | --- | --- | --- | --- |
# | Динамическая вязкость | $\eta$ | $1\,\text{Па}\cdot \text{с}$ | $10\,\text{П}$ (пуаз) |
# | Кинематическая вязкость | $\nu_\mathrm{kin}=\eta/\rho$ | $1\,\dfrac{\text{м}^{2}}{\text{с}}$ | $10^4\,\text{Ст}$ (стокс) |
# | Коэффициент диффузии | $D_\mathrm{diff}$ | $1\,\dfrac{\text{м}^{2}}{\text{с}}$ | $10^4\,\dfrac{\text{см}^{2}}{\text{с}}$ |
# | Теплопроводность | $\kappa$ | $1\,\dfrac{\text{Вт}}{\text{м}\cdot \text{К}}$ | $10^5\,\dfrac{\text{эрг}}{\text{см}\cdot \text{с}\cdot \text{К}}$ |
#
# Не путайте динамическую вязкость $\eta\,\text{с}$ кинематической $\nu_\mathrm{kin}$. В теплопроводности температура входит в размерность: $[\kappa]=\dfrac{m\ell}{t^3\Theta}$.

# %% [markdown]
# <h2 id="equivalents">Энергия, масса и квантовые соотношения</h2>

# %% [markdown]
# ### Энергия: эВ, Дж, эрг и калория
#
# | Из какой единицы | В какую | Соотношение |
# | --- | --- | --- |
# | $1\,\text{эВ}$ | $\text{Дж}$ | $1.602176634\times10^{-19}\,\text{Дж}$, точно |
# | $1\,\text{эВ}$ | $\text{эрг}$ | $1.602176634\times10^{-12}\,\text{эрг}$, точно |
# | $1\,\text{Дж}$ | $\text{эВ}$ | $\approx6.241509074\times10^{18}\,\text{эВ}$ |
# | $1\,\text{эрг}$ | $\text{Дж}$ | $10^{-7}\,\text{Дж}$, точно |
# | $1\,\text{эрг}$ | $\text{эВ}$ | $\approx6.241509074\times10^{11}\,\text{эВ}$ |
# | $1\,\text{кэВ}$ | $\text{эВ}$ | $10^3\,\text{эВ}$ |
# | $1\,\text{МэВ}$ | $\text{эВ}$ | $10^6\,\text{эВ}$ |
# | $1\,\text{ГэВ}$ | $\text{эВ}$ | $10^9\,\text{эВ}$ |
# | 1 термохимическая калория | $\text{Дж}$ | $4.184\,\text{Дж}$, точно |
#
# **Пример:** $5\,\text{МэВ}$ = $5\times10^6\times1.602176634\times10^{-19}\,\text{Дж}$ $\approx8.01088317\times10^{-13}\,\text{Дж}$.

# %% [markdown]
# ### Масса и энергия покоя
#
# Масса выражается в $\dfrac{\text{эВ}}{c^2}$, энергия — в $\text{эВ}$. Их связывает $E_0=mc^2$.
#
# | Соотношение | Значение |
# | --- | --- |
# | $1\,\dfrac{\text{эВ}}{c^2}$ | $\approx1.782661922\times10^{-36}\,\text{кг}$ |
# | $1\,\dfrac{\text{МэВ}}{c^2}$ | $\approx1.782661922\times10^{-30}\,\text{кг}$ |
# | $1\,\dfrac{\text{ГэВ}}{c^2}$ | $\approx1.782661922\times10^{-27}\,\text{кг}$ |
# | $1\,\text{кг}$ | $\approx5.609588604\times10^{35}\,\dfrac{\text{эВ}}{c^2}$ |
# | $1\,\mathrm{u}=1\,\mathrm{Da}$ | $\approx931.49410372\,\dfrac{\text{МэВ}}{c^2}$ |
#
# Например, масса электрона $m_e\approx0.51099895\,\dfrac{\text{МэВ}}{c^2}$, а его энергия покоя $m_ec^2\approx0.51099895\,\text{МэВ}$.

# %% [markdown]
# ### Фотоны: энергия, частота и длина волны
#
# $$
# E=h\nu=\hbar\omega=\frac{hc}{\lambda}=hc\tilde\nu,
# \qquad \omega=2\pi\nu,\quad \tilde\nu=\frac{1}{\lambda},\quad k=\frac{2\pi}{\lambda}.
# $$
#
# Здесь $\lambda$ — длина волны **в вакууме**. Спектроскопическое волновое число $\tilde\nu$ и угловое волновое число $k$ отличаются в $2\pi$ раз.
#
# | Связь | Практическая запись |
# | --- | --- |
# | Энергия → частота | $\nu\,[\mathrm{Hz}]\approx2.417989242\times10^{14}\,E\,[\mathrm{eV}]$ |
# | Энергия → угловая частота | $\omega\,[\mathrm{s}^{-1}]\approx1.519267448\times10^{15}\,E\,[\mathrm{eV}]$ |
# | Энергия ↔ длина волны | $E\,[\mathrm{eV}]\,\lambda\,[\mathrm{nm}]\approx1239.841984$ |
# | Энергия → волновое число | $\tilde\nu\,[\mathrm{cm}^{-1}]\approx8065.543937\,E\,[\mathrm{eV}]$ |
# | $1\,\text{см}^{-1}$ → энергия | $\approx1.239841984\times10^{-4}\,\text{эВ}$ |
# | $1\,\text{м}^{-1}$ → энергия | $\approx1.239841984\times10^{-6}\,\text{эВ}$ |
#
# **Пример:** фотон с длиной волны $500\,\text{нм}$ имеет энергию $1239.841984/500\approx2.47968\,\text{эВ}$.

# %% [markdown]
# ### Температура и тепловая энергия
#
# $$
# E_T=k_\mathrm{B}T,\qquad k_\mathrm{B}\approx8.617333262\times10^{-5}\ \mathrm{eV/K}.
# $$
#
# | Соотношение | Значение |
# | --- | --- |
# | $1\,\text{К}$ → $k_\mathrm{B}T$ | $\approx8.617333262\times10^{-5}\,\text{эВ}$ |
# | $1\,\text{эВ}$ → температура при $E_T=k_\mathrm{B}T$ | $\approx11604.51812\,\text{К}$ |
# | При $300\,\text{К}$ | $k_\mathrm{B}T\approx0.0258520\,\text{эВ}$ = $25.8520\,\text{мэВ}$ |
# | Цельсий → кельвин | $T\,[\mathrm K]=t\,[{}^\circ\mathrm C]+273.15$ |
#
# $k_\mathrm{B}T$ — энергетический масштаб. Например, средняя поступательная энергия частицы классического одноатомного идеального газа равна $3k_\mathrm{B}T/2$, а не $k_\mathrm{B}T$.

# %% [markdown]
# ### Атомные и естественные единицы
#
# | Единица или комбинация | Эквивалент |
# | --- | --- |
# | 1 боровский радиус $a_0$ | $\approx0.05291772105\,\text{нм}$ |
# | 1 хартри $E_\mathrm h$ | $\approx27.211386246\,\text{эВ}$ |
# | 1 ридберг $E_\mathrm{Ry}=E_\mathrm h/2$ | $\approx13.605693123\,\text{эВ}$ |
# | $\hbar c$ | $\approx197.3269804\,\text{МэВ}\cdot \text{фм}$ = $197.3269804\,\text{эВ}\cdot \text{нм}$ |
# | $hc$ | $\approx1239.841984\,\text{эВ}\cdot \text{нм}$ |
# | $\hbar$ | $\approx6.582119569\times10^{-16}\,\text{эВ}\cdot \text{с}$ |
# | $1\,\text{ГэВ}^{-1}$ в единицах длины | $\approx0.1973269804\,\text{фм}$, после умножения на $\hbar c$ |
# | $1\,\text{ГэВ}^{-1}$ в единицах времени | $\approx6.582119569\times10^{-25}\,\text{с}$, после умножения на $\hbar$ |
# | $1\,\text{ГэВ}^{-2}$ в единицах сечения | $\approx0.3893793721\,\text{мб}$, после умножения на $(\hbar c)^2$ |
#
# В естественных единицах $\hbar=c=1$ энергия, масса и импульс имеют одну размерность; длина и время — обратную энергию. В атомных единицах обычно полагают $m_e=e=\hbar=4\pi\varepsilon_0=1$. Это **разные соглашения**.

# %% [markdown]
# <h2 id="dimensions">Размерное представление</h2>
#
# Используются обозначения **$m$ — масса, $\ell$ — длина, $t$ — время, $q$ — заряд**, а $\Theta$ — размерность температуры. Например, $[F]=m\ell/t^2$. Столбец «Обозначение» содержит символ самой величины; два следующих столбца — её размерности.
#
# В СИ заряд — независимая размерность, $[I]=q/t$. В электростатической и гауссовой СГС из закона Кулона следует $[q]=m^{1/2}\ell^{3/2}/t$. Для электрических величин ниже используется электростатическая СГС, для магнитных — гауссова. В частности, размерность индуктивности $t^2/\ell$ относится именно к электростатическим единицам.
#
# Одни и те же буквы могут обозначать разные величины: $U$ — энергию или напряжение, $m$ — массу или магнитный момент, $\rho$ — плотность массы, заряда или удельное сопротивление. Название строки задаёт смысл.

# %% [markdown]
# ### Механика: движение, масса и геометрия
#
# | Величина | Обозначение | СИ: размерность | СГС: размерность |
# | --- | --- | --- | --- |
# | Длина | $\ell$ | $\ell$ | $\ell$ |
# | Площадь | $S$ | $\ell^2$ | $\ell^2$ |
# | Объём | $V$ | $\ell^3$ | $\ell^3$ |
# | Масса | $m$ | $m$ | $m$ |
# | Время | $t$ | $t$ | $t$ |
# | Скорость | $\mathbf{v}$ | $\dfrac{\ell}{t}$ | $\dfrac{\ell}{t}$ |
# | Ускорение | $a$ | $\dfrac{\ell}{t^2}$ | $\dfrac{\ell}{t^2}$ |
# | Частота | $f,\nu$ | $\dfrac{1}{t}$ | $\dfrac{1}{t}$ |
# | Вихревость | $\zeta$ | $\dfrac{1}{t}$ | $\dfrac{1}{t}$ |
# | Плотность массы | $\rho$ | $\dfrac{m}{\ell^3}$ | $\dfrac{m}{\ell^3}$ |
# | Импульс | $p$ | $\dfrac{m\ell}{t}$ | $\dfrac{m\ell}{t}$ |
# | Плотность импульса | $p/V$ | $\dfrac{m}{\ell^2 t}$ | $\dfrac{m}{\ell^2 t}$ |

# %% [markdown]
# ### Механика: сила, энергия и давление
#
# | Величина | Обозначение | СИ: размерность | СГС: размерность |
# | --- | --- | --- | --- |
# | Сила | $F$ | $\dfrac{m\ell}{t^2}$ | $\dfrac{m\ell}{t^2}$ |
# | Энергия | $U$ | $\dfrac{m\ell^2}{t^2}$ | $\dfrac{m\ell^2}{t^2}$ |
# | Работа | $W$ | $\dfrac{m\ell^2}{t^2}$ | $\dfrac{m\ell^2}{t^2}$ |
# | Плотность энергии | $w,\varepsilon$ | $\dfrac{m}{\ell t^2}$ | $\dfrac{m}{\ell t^2}$ |
# | Мощность | $P$ | $\dfrac{m\ell^2}{t^3}$ | $\dfrac{m\ell^2}{t^3}$ |
# | Плотность мощности | $P/V$ | $\dfrac{m}{\ell t^3}$ | $\dfrac{m}{\ell t^3}$ |
# | Давление | $p$ | $\dfrac{m}{\ell t^2}$ | $\dfrac{m}{\ell t^2}$ |

# %% [markdown]
# ### Перенос и температура
#
# | Величина | Обозначение | СИ: размерность | СГС: размерность |
# | --- | --- | --- | --- |
# | Температура | $T$ | $\Theta$ | $\Theta$ |
# | Динамическая вязкость | $\eta,\mu$ | $\dfrac{m}{\ell t}$ | $\dfrac{m}{\ell t}$ |
# | Кинематическая вязкость | $\nu_\mathrm{kin}$ | $\dfrac{\ell^2}{t}$ | $\dfrac{\ell^2}{t}$ |
# | Коэффициент диффузии | $\mathcal{D}$ | $\dfrac{\ell^2}{t}$ | $\dfrac{\ell^2}{t}$ |
# | Теплопроводность | $\kappa$ | $\dfrac{m\ell}{t^3\Theta}$ | $\dfrac{m\ell}{t^3\Theta}$ |

# %% [markdown]
# ### Электричество: заряд, ток и поле
#
# | Величина | Обозначение | СИ: размерность | СГС: размерность |
# | --- | --- | --- | --- |
# | Заряд | $q$ | $q$ | $\dfrac{m^{1/2}\ell^{3/2}}{t}$ |
# | Плотность заряда | $\rho$ | $\dfrac{q}{\ell^3}$ | $\dfrac{m^{1/2}}{\ell^{3/2}t}$ |
# | Ток | $I$ | $\dfrac{q}{t}$ | $\dfrac{m^{1/2}\ell^{3/2}}{t^2}$ |
# | Плотность тока | $\boldsymbol{J}, \boldsymbol{j}$ | $\dfrac{q}{\ell^2 t}$ | $\dfrac{m^{1/2}}{\ell^{1/2}t^2}$ |
# | Потенциал | $V,\phi$ | $\dfrac{m\ell^2}{t^2 q}$ | $\dfrac{m^{1/2}\ell^{1/2}}{t}$ |
# | Напряжение | $U$ | $\dfrac{m\ell^2}{t^2q}$ | $\dfrac{m^{1/2}\ell^{1/2}}{t}$ |
# | ЭДС | $\mathcal{E}$ | $\dfrac{m\ell^2}{t^2 q}$ | $\dfrac{m^{1/2}\ell^{1/2}}{t}$ |
# | Электрическое поле | $\mathbf{E}$ | $\dfrac{m\ell}{t^2 q}$ | $\dfrac{m^{1/2}}{\ell^{1/2}t}$ |
# | Электрическое смещение | $\mathbf{D}$ | $\dfrac{q}{\ell^2}$ | $\dfrac{m^{1/2}}{\ell^{1/2}t}$ |
# | Поляризация | $\mathbf{P}$ | $\dfrac{q}{\ell^2}$ | $\dfrac{m^{1/2}}{\ell^{1/2}t}$ |

# %% [markdown]
# ### Электричество: элементы цепей
#
# | Величина | Обозначение | СИ: размерность | СГС: размерность |
# | --- | --- | --- | --- |
# | Ёмкость | $C$ | $\dfrac{t^2 q^2}{m\ell^2}$ | $\ell$ |
# | Сопротивление | $R$ | $\dfrac{m\ell^2}{t q^2}$ | $\dfrac{t}{\ell}$ |
# | Импеданс | $Z$ | $\dfrac{m\ell^2}{t q^2}$ | $\dfrac{t}{\ell}$ |
# | Проводимость | $g$ | $\dfrac{tq^2}{m\ell^2}$ | $\dfrac{\ell}{t}$ |
# | Удельное сопротивление | $\eta,\rho$ | $\dfrac{m\ell^3}{t q^2}$ | $t$ |
# | Удельная проводимость | $\sigma$ | $\dfrac{tq^2}{m\ell^3}$ | $\dfrac{1}{t}$ |
# | Индуктивность (СГС: электростатическая) | $L$ | $\dfrac{m\ell^2}{q^2}$ | $\dfrac{t^2}{\ell}$ |

# %% [markdown]
# ### Магнетизм и свойства среды
#
# | Величина | Обозначение | СИ: размерность | СГС: размерность |
# | --- | --- | --- | --- |
# | Магнитная индукция | $\mathbf{B}$ | $\dfrac{m}{t q}$ | $\dfrac{m^{1/2}}{\ell^{1/2}t}$ |
# | Напряжённость магнитного поля | $\mathbf{H}$ | $\dfrac{q}{\ell t}$ | $\dfrac{m^{1/2}}{\ell^{1/2}t}$ |
# | Магнитный поток | $\Phi$ | $\dfrac{m\ell^2}{t q}$ | $\dfrac{m^{1/2}\ell^{3/2}}{t}$ |
# | Векторный потенциал | $\mathbf{A}$ | $\dfrac{m\ell}{t q}$ | $\dfrac{m^{1/2}\ell^{1/2}}{t}$ |
# | Магнитный момент | $m,\mu$ | $\dfrac{\ell^2 q}{t}$ | $\dfrac{m^{1/2}\ell^{5/2}}{t}$ |
# | Намагниченность | $\mathbf{M}$ | $\dfrac{q}{\ell t}$ | $\dfrac{m^{1/2}}{\ell^{1/2}t}$ |
# | Магнитодвижущая сила | $\mathcal{M}$ | $\dfrac{q}{t}$ | $\dfrac{m^{1/2}\ell^{1/2}}{t}$ |
# | Магнитное сопротивление | $\mathcal{R}$ | $\dfrac{q^2}{m\ell^2}$ | $\dfrac{1}{\ell}$ |
# | Диэлектрическая проницаемость | $\varepsilon$ | $\dfrac{t^2 q^2}{m\ell^3}$ | $1$ |
# | Магнитная проницаемость | $\mu$ | $\dfrac{m\ell}{q^2}$ | $1$ |
#
# В строках проницаемостей в СИ приведены абсолютные $\varepsilon$ и $\mu$; в гауссовой СГС соответствующие коэффициенты безразмерны. Их определения учитывайте при переводе формул. Размерности магнитных величин нельзя получать одной лишь подстановкой размерности заряда: в гауссовых формулах появляются множители $c$.
#
# Равенство размерностей проверяет формулу, но не определяет безразмерные коэффициенты $2$, $\pi$ или $4\pi$.

# %% [markdown]
# ## Источники
#
# - [BIPM: Международная система единиц, действующая брошюра СИ](https://www.bipm.org/en/publications/si-brochure).
# - [NIST SP 811: перевод единиц, приложение B](https://nvlpubs.nist.gov/nistpubs/Legacy/SP/nistspecialpublication811e2008.pdf). Источник коэффициентов перевода; определения современной СИ см. в BIPM.
# - [NIST: единицы магнитных величин](https://www.nist.gov/document/magneticunitspdf) — в частности, различие переводов $H$, $M$ и $4\pi M$.
# - [NIST / CODATA 2022: константы и энергетические эквиваленты](https://physics.nist.gov/cuu/pdf/all.pdf).
#
# Проверено: 22 сентября 2026 года. Десятичные коэффициенты с $\approx$ округлены. Для высокоточных электромагнитных переводов следует учитывать современное определение СИ и неопределённость $\mu_0$.
